# %%
import matplotlib.pyplot as plt
import numpy as np
import spectra

s = spectra.Spectra()

N = 10
x = np.linspace(0, 10, N, endpoint=True)
random_data = np.random.rand(N)

plt.plot(x, random_data)

xmin = 0
xmax = 11.5
npoints = 200
fwhm = 0.15

x_new, y_new = s.lorenzian_broaden(x, random_data, xmin, xmax, npoints, fwhm)

plt.plot(x_new, y_new)
